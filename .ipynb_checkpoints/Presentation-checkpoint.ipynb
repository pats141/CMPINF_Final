# %% [markdown]
# # CMPINF Final Project
# ## Evan Tall, Jerry Huang, Hailey Trampel
#
# ## How we ranked 'bestness':
# * How **safe** the neighborhood is
# * How many **hospitals** the neighborhood has
# * How many **bridges** the neighborhood has

# %%
import pandas as pd
import numpy as np
import ssl

# %% [markdown]
# ## Analyzing how safe the neighborhoods are
# First, we imported the data for Pittsburgh Area arrests, as reported by the Pittsburgh Police.

# %%
pgh_crime_data = pd.read_csv("crime_data.csv")
pgh_crime_data["INCIDENTNEIGHBORHOOD"].value_counts().sort_values(ascending=True).head(10)
# Out:
# Mt. Oliver Neighborhood     2
# Troy Hill-Herrs Island      6
# Mt. Oliver Boro            12
# Ridgemont                  13
# Regent Square              19
# Swisshelm Park             20
# New Homestead              22
# Central Northside          23
# Chartiers City             23
# East Carnegie              27
# Name: INCIDENTNEIGHBORHOOD, dtype: int64

# %%
pgh_crime_data["INCIDENTNEIGHBORHOOD"].value_counts().head(10)
# Out:
# Central Business District    2131
# South Side Flats             1953
# Carrick                      1313
# East Allegheny               1235
# Homewood South               1138
# Homewood North               1036
# East Liberty                  995
# Marshall-Shadeland            853
# Mount Washington              838
# Bluff                         783
# Name: INCIDENTNEIGHBORHOOD, dtype: int64

# %%
public_safety_data = pd.read_csv('public_safety_data.csv')
tempt=public_safety_data.sort_values(by = '#Part 1 (Major Crime) Reports (2010)', ascending=True)
tempt[['Neighborhood','#Part 1 (Major Crime) Reports (2010)']]
# Out:
#                  Neighborhood  #Part 1 (Major Crime) Reports (2010)
# 31                  Fairywood                                     3
# 54              New Homestead                                     7
# 20             Chartiers City                                     9
# 26              East Carnegie                                     9
# 35                 Glen Hazel                                    10
# 53                 Mt. Oliver                                    12
# 80                Summer Hill                                    13
# 58                    Oakwood                                    14
# 77                  St. Clair                                    14
# 66                  Ridgemont                                    14
# 37                       Hays                                    15
# 21                    Chateau                                    16
# 4           Arlington Heights                                    19
# 86                   West End                                    23
# 11                    Bon Air                                    26
# 81             Swisshelm Park                                    28
# 30                     Esplen                                    31
# 45              Lincoln Place                                    32
# 64                Polish Hill                                    34
# 73              Spring Garden                                    36
# 70                South Shore                                    37
# 1              Allegheny West                                    38
# 65              Regent Square                                    38
# 89                    Windgap                                    41
# 6           Bedford Dwellings                                    42
# 84                 Upper Hill                                    45
# 3                   Arlington                                    50
# 24           Duquesne Heights                                    55
# 42              Homewood West                                    56
# 88                   Westwood                                    57
# ..                        ...                                   ...
# 75        Squirrel Hill North                                   148
# 79             Strip District                                   155
# 38                  Hazelwood                                   159
# 2                   Allentown                                   159
# 83                  Troy Hill                                   163
# 82            Terrace Village                                   163
# 17      Central Lawrenceville                                   177
# 39              Highland Park                                   182
# 34                   Garfield                                   182
# 55              North Oakland                                   182
# 7                   Beechview                                   193
# 40             Homewood North                                   198
# 72          South Side Slopes                                   210
# 61                Perry South                                   221
# 68                   Sheraden                                   222
# 49         Marshall-Shadeland                                   222
# 43                  Knoxville                                   223
# 25             East Allegheny                                   234
# 19            Central Oakland                                   236
# 13                  Brookline                                   241
# 12           Brighton Heights                                   241
# 41             Homewood South                                   243
# 76        Squirrel Hill South                                   331
# 52           Mount Washington                                   434
# 15                    Carrick                                   453
# 9                  Bloomfield                                   453
# 28               East Liberty                                   488
# 67                  Shadyside                                   623
# 71           South Side Flats                                   669
# 16  Central Business District                                   789
#
# [90 rows x 2 columns]

# %%
pgh_safety_data["Neighborhood"].value_counts().head(10)
# Out:
# Allegheny Center         1
# Brookline                1
# Marshall-Shadeland       1
# Hazelwood                1
# South Side Flats         1
# Central Northside        1
# Westwood                 1
# Glen Hazel               1
# Spring Hill-City View    1
# South Side Slopes        1
# Name: Neighborhood, dtype: int64

# %% [markdown]
# ## Counting the number of bridges per region

# %%
pgh_bridge_data = pd.read_csv("bridge_data.csv")
pgh_bridge_data["neighborhood"].value_counts().head(10)
pgh_bridge_data["neighborhood"].value_counts()
# Out:
# Squirrel Hill South          15
# Shadyside                     7
# Troy Hill                     7
# Central Business District     6
# Hays                          5
# South Side Flats              5
# Overbrook                     5
# South Side Slopes             5
# Oakwood                       5
# Hazelwood                     5
# Name: neighborhood, dtype: int64
